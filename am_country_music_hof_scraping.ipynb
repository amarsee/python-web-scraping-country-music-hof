# %% [markdown]
# In this exercise, your objective is to use BeautifulSoup in order to obtain a dataset of all Country Music Hall of Fame inductees. This information is available at https://countrymusichalloffame.org/hall-of-fame/members/, but you will take the contents of this website and convert it into a pandas DataFrame.

# %% [markdown]
# The website splits the members across multiple pages, but start by just working on the first page. Later on in the exercise, you'll take what you've done for the first page and apply it across all pages.

# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import re

# %% [markdown]
# ### 1. Start by using either the inspector or by viewing the page source. Can you identify a tag that might be helpful for finding the names of all inductees? Make use of this to create a list containing just the names of each inductee.

# %%
website_url = 'https://countrymusichalloffame.org/hall-of-fame/members/page/2'
response = requests.get(website_url)

# %%
soup = BeautifulSoup(response.content, 'lxml')

# %%
artist_names = soup.find_all('h3')

# %%
artist_names
# Out:
# [<h3>Bobby Braddock</h3>,
#  <h3>Harold Bradley</h3>,
#  <h3>Jerry Bradley</h3>,
#  <h3>Owen Bradley</h3>,
#  <h3>Rod Brasfield</h3>,
#  <h3>Garth Brooks</h3>,
#  <h3>Brooks &amp; Dunn</h3>,
#  <h3>Jim Ed Brown</h3>,
#  <h3>Jim Ed Brown and the Browns</h3>]

# %%
artist_list = []
for artist in artist_names:
    artist_list.append(artist.text)

# %%
artist_list = [artist.text for artist in artist_names]

# %%
artist_list
# Out:
# ['Bobby Braddock',
#  'Harold Bradley',
#  'Jerry Bradley',
#  'Owen Bradley',
#  'Rod Brasfield',
#  'Garth Brooks',
#  'Brooks & Dunn',
#  'Jim Ed Brown',
#  'Jim Ed Brown and the Browns']

# %% [markdown]
# ### 2. Next, try and find a tag that could be used to find the year that each member was inducted. Extract these into a list. When you do this, be sure to only include the year and not the full text. For example, for Roy Acuff, the list entry should be "1962" and not "Inducted 1962". Double-check that the resulting list has the correct number of elements and is in the same order as your inductees list.

# %%
year_inducted_soup = soup.find_all('p')

# %%
year_inducted_soup = soup.find_all('div', attrs = {'class': "vertical-card_content--copy"})

# %%
len(year_inducted_soup)
# Out:
# 9

# %%
year_inducted_soup[0].text
# Out:
# '\n\n                    Inducted 2011                  \n'

# %%
years_inducted = [int(re.findall("\d+", year_str.text)[0]) for year_str in year_inducted_soup 
                      if re.match("\s+Inducted\s\d+\s+", year_str.text)]

# %%
years_inducted
# Out:
# [2011, 2006, 2019, 1974, 1987, 2012, 2019, 2015, 2015]

# %%
years =[]
# iteration = 0
for x in year_inducted_soup:
#     print()
    years.append(int(x.text.strip().replace('Inducted ',"")))
years
# Out:
# [2011, 2006, 2019, 1974, 1987, 2012, 2019, 2015, 2015]

# %%
new_years =[]
for i in range(len(years)):
    new_years.append(years[i] - 2000)
    
new_years
# Out:
# [11, 6, 19, -26, -13, 12, 19, 15, 15]

# %% [markdown]
# ### 3. Take the two lists you created on parts 1 and 2 and convert it into a pandas DataFrame.

# %%
hof_df = pd.DataFrame(
    {
        "artist": artist_list, 
        "year_inducted": years_inducted
    }
)

# %%
list(zip(artist_list, years_inducted))
# Out:
# [('Bobby Braddock', 2011),
#  ('Harold Bradley', 2006),
#  ('Jerry Bradley', 2019),
#  ('Owen Bradley', 1974),
#  ('Rod Brasfield', 1987),
#  ('Garth Brooks', 2012),
#  ('Brooks & Dunn', 2019),
#  ('Jim Ed Brown', 2015),
#  ('Jim Ed Brown and the Browns', 2015)]

# %%
results_together = pd.DataFrame(list(zip(artist_list, years_inducted)), columns = ['Artist', 'Year'])
results_together
# Out:
#                         Artist  Year
# 0               Bobby Braddock  2011
# 1               Harold Bradley  2006
# 2                Jerry Bradley  2019
# 3                 Owen Bradley  1974
# 4                Rod Brasfield  1987
# 5                 Garth Brooks  2012
# 6                Brooks & Dunn  2019
# 7                 Jim Ed Brown  2015
# 8  Jim Ed Brown and the Browns  2015

# %%
hof_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist         9 non-null      object
#  1   year_inducted  9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 272.0+ bytes

# %% [markdown]
# ### 4. Now, you need to take what you created for the first page and apply it across the rest of the pages so that you can scrape all inductees. Notice that when you click the next page button at the bottom of the page that the url changes to "https://countrymusichalloffame.org/hall-of-fame/members/page/2". Check that the code that you wrote for the first page still works for page 2. Once you have verified that your code will still work, write a for loop that will cycle through all 16 pages and build a DataFrame containing all inductees and the year of their induction.

# %%
test_list = [1, 2, 3, 4]
test_list.extend([5, 6, 7, 8])
test_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
all_artists = []
all_years_inducted = []
for page in range(1, 17):
#     print(f"Page Number: {page}")
    if page == 1:
        hof_url = "https://countrymusichalloffame.org/hall-of-fame/members/"
    else:
        hof_url = f"https://countrymusichalloffame.org/hall-of-fame/members/page/{page}"
    response = requests.get(hof_url)
    soup = BeautifulSoup(response.content, 'lxml')
    
    artists_page = soup.find_all('h3')
    artist_list_page = [artist.text for artist in artists_page]
    
    years_inducted_page = soup.find_all('p')
    years_inducted_list_page = [int(re.findall("\d+", year_str.text)[0]) for year_str in years_inducted_page 
                      if re.match("\s+Inducted\s\d+\s+", year_str.text)]
    
#     print(f"Artists: {artist_list_page}")
#     print(f"Years: {years_inducted_list_page}")
#     print("\n")
    
    all_artists.extend(artist_list_page)
    all_years_inducted.extend(years_inducted_list_page)

# %%
hof_df_all = pd.DataFrame(
    {
        "artist": all_artists, 
        "year_inducted": all_years_inducted
    }
)
hof_df_all.head()
# Out:
#           artist  year_inducted
# 0      Roy Acuff           1962
# 1        Alabama           2005
# 2  Bill Anderson           2001
# 3    Eddy Arnold           1966
# 4    Chet Atkins           1973

# %%
hof_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist         140 non-null    object
#  1   year_inducted  140 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# ### 5. Create a visual using the data that you scraped. Prepare a short (<5 minute) presentation.

# %% [markdown]
# ### 6. Bonus Question: If you navigate to Roy Acuff's page, you will see that his date of birth and date of death are listed towards the top of the page, along with his birthplace. Write some code that will extract these three values. Once you get it working for Roy Acuff, figure out how you can automatically extract these values across the whole dataset of artists. In doing this, you'll need to figure out a way to automatically determine the correct urls for each artist. Note also that not every artist will have these three values, so write your code in a way that it can handle cases where these values are missing. Alabama is one such example.

# %%
test_string = "Birth: September 15, 1903 - Death: November 23, 1992 Birthplace: Maynardville, Tennessee"

# %%
re.findall("Birth: (\w+)", test_string)
# Out:
# ['September']

# %%
re.sub("[a-z]", "", test_string)
# Out:
# 'B: S 15, 1903 - D: N 23, 1992 B: M, T'

# %%
roy_url = 'https://countrymusichalloffame.org/artist/roy-acuff/'
roy_response = requests.get(roy_url)
roy_soup = BeautifulSoup(roy_response.content, 'lxml')

# %%
info_style = 'margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;'
roy_info = roy_soup.find_all('p', attrs = {'style': info_style})

# %%
info_style = 'margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;'
births = []
deaths = []
birthplaces = []
for artist_name in hof_df_all["artist"].to_list():
    artist_page_name = '-'.join(re.findall("\w+", artist_name)).lower()
#     print(artist_name.lower().replace(" ", "-").replace(".", "").replace('“', "").replace('”', ""))
    print(artist_page_name)

    artist_url = f'https://countrymusichalloffame.org/artist/{artist_page_name}/'
    artist_response = requests.get(artist_url)
    soup = BeautifulSoup(artist_response.content, 'lxml')
    print(artist_url)
    
    artist_info = soup.find_all('p', attrs = {'style': info_style})
    if artist_info:
        birthdate = re.findall("Birth: (\w+\s\d+, \d+)\s", artist_info[0].text)
        deathdate = re.findall("Death: (\w+\s\d+, \d+)\s", artist_info[0].text)
#         birthplace = re.findall("Birthplace: ([\w|\s|\(|\)]+,\s.+)\s", artist_info[0].text)
        birthplace = re.findall("Birthplace: (.+)\s$", artist_info[0].text)
    else:
        birthdate = [""]
        deathdate = [""]
        birthplace = [""]
    if len(birthdate) == 0:
        birthdate = [""]
    if len(deathdate) == 0:
        deathdate = [""]
    if len(birthplace) == 0:
        birthplace = [""]
    print(artist_info)
    
#     try: 
#         birthdate = re.findall("Birth: (\w+\s\d+, \d+)\s-", artist_info[0].text)
#         if len(birthdate) == 0 :
#             birthdate = [""]
#     except:
#         birthdate = [""]
    print(f"Birth Date: {birthdate}")
#     try: 
#         deathdate = re.findall("Death: (\w+\s\d+, \d+)\s", artist_info[0].text)
#         if len(deathdate) == 0 :
#             deathdate = [""]
#     except:
#         deathdate = [""]
    print(f"Death Date: {deathdate}")
#     try:
#         birthplace = re.findall("Birthplace: ([\w|\s]+,\s.+)\s", artist_info[0].text)
#         if len(birthplace) == 0 :
#             birthplace = [""]
#     except:
#         birthplace = [""]
    print(f"Birthplace: {birthplace}")
    
    
    print("==========================")
    births.extend(birthdate)
    deaths.extend(deathdate)
    birthplaces.extend(birthplace)
# Out:
# roy-acuff
# https://countrymusichalloffame.org/artist/roy-acuff/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 15, 1903 - Death: November 23, 1992 <br/> Birthplace: Maynardville, Tennessee </p>]
# Birth Date: ['September 15, 1903']
# Death Date: ['November 23, 1992']
# Birthplace: ['Maynardville, Tennessee']
# ==========================
# alabama
# https://countrymusichalloffame.org/artist/alabama/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# bill-anderson
# https://countrymusichalloffame.org/artist/bill-anderson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 1, 1937 <br/> Birthplace: Columbia, South Carolina </p>]
# Birth Date: ['November 1, 1937']
# Death Date: ['']
# Birthplace: ['Columbia, South Carolina']
# ==========================
# eddy-arnold
# https://countrymusichalloffame.org/artist/eddy-arnold/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 15, 1918 - Death: May 8, 2008 <br/> Birthplace: Henderson, Tennessee </p>]
# Birth Date: ['May 15, 1918']
# Death Date: ['May 8, 2008']
# Birthplace: ['Henderson, Tennessee']
# ==========================
# chet-atkins
# https://countrymusichalloffame.org/artist/chet-atkins/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: June 20, 1924 - Death: June 30, 2001 <br/> Birthplace: Luttrell, Tennessee </p>]
# Birth Date: ['June 20, 1924']
# Death Date: ['June 30, 2001']
# Birthplace: ['Luttrell, Tennessee']
# ==========================
# gene-autry
# https://countrymusichalloffame.org/artist/gene-autry/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 29, 1907 - Death: October 2, 1998 <br/> Birthplace: Tioga, Texas </p>]
# Birth Date: ['September 29, 1907']
# Death Date: ['October 2, 1998']
# Birthplace: ['Tioga, Texas']
# ==========================
# deford-bailey
# https://countrymusichalloffame.org/artist/deford-bailey/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 14, 1899 - Death: July 2, 1982 <br/> Birthplace: Smith County, Tennessee </p>]
# Birth Date: ['December 14, 1899']
# Death Date: ['July 2, 1982']
# Birthplace: ['Smith County, Tennessee']
# ==========================
# bobby-bare
# https://countrymusichalloffame.org/artist/bobby-bare/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 7, 1935 <br/> Birthplace: Lawrence County, Ohio </p>]
# Birth Date: ['April 7, 1935']
# Death Date: ['']
# Birthplace: ['Lawrence County, Ohio']
# ==========================
# johnny-bond
# https://countrymusichalloffame.org/artist/johnny-bond/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: June 1, 1915 - Death: June 12, 1978 <br/> Birthplace: Enville, Oklahoma </p>]
# Birth Date: ['June 1, 1915']
# Death Date: ['June 12, 1978']
# Birthplace: ['Enville, Oklahoma']
# ==========================
# bobby-braddock
# https://countrymusichalloffame.org/artist/bobby-braddock/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 5, 1940 <br/> Birthplace: Lakeland, Florida </p>]
# Birth Date: ['August 5, 1940']
# Death Date: ['']
# Birthplace: ['Lakeland, Florida']
# ==========================
# harold-bradley
# https://countrymusichalloffame.org/artist/harold-bradley/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 2, 1926 <br/> Birthplace: Nashville, Tennessee </p>]
# Birth Date: ['January 2, 1926']
# Death Date: ['']
# Birthplace: ['Nashville, Tennessee']
# ==========================
# jerry-bradley
# https://countrymusichalloffame.org/artist/jerry-bradley/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 30, 1940 <br/> Birthplace: Nashville, TN </p>]
# Birth Date: ['January 30, 1940']
# Death Date: ['']
# Birthplace: ['Nashville, TN']
# ==========================
# owen-bradley
# https://countrymusichalloffame.org/artist/owen-bradley/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 21, 1915 - Death: January 7, 1998 <br/> Birthplace: Westmoreland, Tennessee </p>]
# Birth Date: ['October 21, 1915']
# Death Date: ['January 7, 1998']
# Birthplace: ['Westmoreland, Tennessee']
# ==========================
# rod-brasfield
# https://countrymusichalloffame.org/artist/rod-brasfield/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 22, 1910 - Death: September 12, 1958 <br/> Birthplace: Smithville, Mississippi </p>]
# Birth Date: ['August 22, 1910']
# Death Date: ['September 12, 1958']
# Birthplace: ['Smithville, Mississippi']
# ==========================
# garth-brooks
# https://countrymusichalloffame.org/artist/garth-brooks/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 7, 1962 <br/> Birthplace: Tulsa, Oklahoma </p>]
# Birth Date: ['February 7, 1962']
# Death Date: ['']
# Birthplace: ['Tulsa, Oklahoma']
# ==========================
# brooks-dunn
# https://countrymusichalloffame.org/artist/brooks-dunn/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# jim-ed-brown
# https://countrymusichalloffame.org/artist/jim-ed-brown/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 1, 1934 - Death: June 11, 2015 <br/> Birthplace: Sparkman, Arkansas </p>]
# Birth Date: ['April 1, 1934']
# Death Date: ['June 11, 2015']
# Birthplace: ['Sparkman, Arkansas']
# ==========================
# jim-ed-brown-and-the-browns
# https://countrymusichalloffame.org/artist/jim-ed-brown-and-the-browns/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# boudleaux-and-felice-bryant
# https://countrymusichalloffame.org/artist/boudleaux-and-felice-bryant/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# glen-campbell
# https://countrymusichalloffame.org/artist/glen-campbell/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 22, 1936 - Death: August 8, 2017 <br/> Birthplace: Delight, Arkansas </p>]
# Birth Date: ['April 22, 1936']
# Death Date: ['August 8, 2017']
# Birthplace: ['Delight, Arkansas']
# ==========================
# bill-carlisle
# https://countrymusichalloffame.org/artist/bill-carlisle/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 19, 1908 - Death: March 17, 2003 <br/> Birthplace: Wakefield, Kentucky </p>]
# Birth Date: ['December 19, 1908']
# Death Date: ['March 17, 2003']
# Birthplace: ['Wakefield, Kentucky']
# ==========================
# carter-family
# https://countrymusichalloffame.org/artist/carter-family/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# johnny-cash
# https://countrymusichalloffame.org/artist/johnny-cash/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 26, 1932 - Death: September 12, 2003 <br/> Birthplace: Kingsland, Arkansas </p>]
# Birth Date: ['February 26, 1932']
# Death Date: ['September 12, 2003']
# Birthplace: ['Kingsland, Arkansas']
# ==========================
# roy-clark
# https://countrymusichalloffame.org/artist/roy-clark/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 15, 1933 - Death: November 15, 2018 <br/> Birthplace: Meherrin, Virginia </p>]
# Birth Date: ['April 15, 1933']
# Death Date: ['November 15, 2018']
# Birthplace: ['Meherrin, Virginia']
# ==========================
# cowboy-jack-clement
# https://countrymusichalloffame.org/artist/cowboy-jack-clement/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 5, 1931 - Death: August 8, 2013 <br/> Birthplace: Whitehaven, Tennessee </p>]
# Birth Date: ['April 5, 1931']
# Death Date: ['August 8, 2013']
# Birthplace: ['Whitehaven, Tennessee']
# ==========================
# patsy-cline
# https://countrymusichalloffame.org/artist/patsy-cline/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 8, 1932 - Death: March 5, 1963 <br/> Birthplace: Winchester, Virginia </p>]
# Birth Date: ['September 8, 1932']
# Death Date: ['March 5, 1963']
# Birthplace: ['Winchester, Virginia']
# ==========================
# hank-cochran
# https://countrymusichalloffame.org/artist/hank-cochran/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 2, 1935 - Death: July 15, 2010 <br/> Birthplace: Isola, Mississippi </p>]
# Birth Date: ['August 2, 1935']
# Death Date: ['July 15, 2010']
# Birthplace: ['Isola, Mississippi']
# ==========================
# paul-cohen
# https://countrymusichalloffame.org/artist/paul-cohen/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 10, 1908 - Death: April 1, 1970 <br/> Birthplace: Chicago, Illinois </p>]
# Birth Date: ['November 10, 1908']
# Death Date: ['April 1, 1970']
# Birthplace: ['Chicago, Illinois']
# ==========================
# floyd-cramer
# https://countrymusichalloffame.org/artist/floyd-cramer/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 27, 1933 - Death: December 31, 1997 <br/> Birthplace: Shreveport, Louisiana </p>]
# Birth Date: ['October 27, 1933']
# Death Date: ['December 31, 1997']
# Birthplace: ['Shreveport, Louisiana']
# ==========================
# vernon-dalhart
# https://countrymusichalloffame.org/artist/vernon-dalhart/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 6, 1883 - Death: September 14, 1948 <br/> Birthplace: Jefferson, Texas </p>]
# Birth Date: ['April 6, 1883']
# Death Date: ['September 14, 1948']
# Birthplace: ['Jefferson, Texas']
# ==========================
# charlie-daniels
# https://countrymusichalloffame.org/artist/charlie-daniels/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 28, 1936 - Death: July 6, 2020 <br/> Birthplace: Wilmington, North Carolina </p>]
# Birth Date: ['October 28, 1936']
# Death Date: ['July 6, 2020']
# Birthplace: ['Wilmington, North Carolina']
# ==========================
# jimmie-davis
# https://countrymusichalloffame.org/artist/jimmie-davis/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 11, 1899 - Death: November 5, 2000 <br/> Birthplace: Beech Springs (near Quitman), Louisiana </p>]
# Birth Date: ['September 11, 1899']
# Death Date: ['November 5, 2000']
# Birthplace: ['Beech Springs (near Quitman), Louisiana']
# ==========================
# jimmy-dean
# https://countrymusichalloffame.org/artist/jimmy-dean/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 10, 1928 - Death: June 13, 2010 <br/> Birthplace: Olton, Texas </p>]
# Birth Date: ['August 10, 1928']
# Death Date: ['June 13, 2010']
# Birthplace: ['Olton, Texas']
# ==========================
# delmore-brothers
# https://countrymusichalloffame.org/artist/delmore-brothers/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# jim-denny
# https://countrymusichalloffame.org/artist/jim-denny/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: 02-28-1911 - Death: 08-27-1963 <br/> Birthplace: Buffalo Valley, Tennessee </p>]
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['Buffalo Valley, Tennessee']
# ==========================
# little-jimmy-dickens
# https://countrymusichalloffame.org/artist/little-jimmy-dickens/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 19, 1920 - Death: January 2, 2015 <br/> Birthplace: Bolt, West Virginia </p>]
# Birth Date: ['December 19, 1920']
# Death Date: ['January 2, 2015']
# Birthplace: ['Bolt, West Virginia']
# ==========================
# ralph-emery
# https://countrymusichalloffame.org/artist/ralph-emery/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 10, 1933 <br/> Birthplace: McEwen, Tennessee </p>]
# Birth Date: ['March 10, 1933']
# Death Date: ['']
# Birthplace: ['McEwen, Tennessee']
# ==========================
# the-everly-brothers
# https://countrymusichalloffame.org/artist/the-everly-brothers/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# flatt-and-scruggs
# https://countrymusichalloffame.org/artist/flatt-and-scruggs/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# jim-foglesong
# https://countrymusichalloffame.org/artist/jim-foglesong/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: July 26, 1922 - Death: July 9, 2013 <br/> Birthplace: Lundale, West Virginia </p>]
# Birth Date: ['July 26, 1922']
# Death Date: ['July 9, 2013']
# Birthplace: ['Lundale, West Virginia']
# ==========================
# red-foley
# https://countrymusichalloffame.org/artist/red-foley/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: June 17, 1910 - Death: September 19, 1968 <br/> Birthplace: Blue Lick, Kentucky </p>]
# Birth Date: ['June 17, 1910']
# Death Date: ['September 19, 1968']
# Birthplace: ['Blue Lick, Kentucky']
# ==========================
# tennessee-ernie-ford
# https://countrymusichalloffame.org/artist/tennessee-ernie-ford/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 13, 1919 - Death: October 17, 1991 <br/> Birthplace: Bristol, Tennessee </p>]
# Birth Date: ['February 13, 1919']
# Death Date: ['October 17, 1991']
# Birthplace: ['Bristol, Tennessee']
# ==========================
# fred-foster
# https://countrymusichalloffame.org/artist/fred-foster/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: July 26, 1931 - Death: February 20, 2019 <br/> Birthplace: Rutherford County, North Carolina </p>]
# Birth Date: ['July 26, 1931']
# Death Date: ['February 20, 2019']
# Birthplace: ['Rutherford County, North Carolina']
# ==========================
# joseph-frank
# https://countrymusichalloffame.org/artist/joseph-frank/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 15, 1900 - Death: May 4, 1952 <br/> Birthplace: Limestone County, Alabama </p>]
# Birth Date: ['April 15, 1900']
# Death Date: ['May 4, 1952']
# Birthplace: ['Limestone County, Alabama']
# ==========================
# lefty-frizzell
# https://countrymusichalloffame.org/artist/lefty-frizzell/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 31, 1928 - Death: July 19, 1975 <br/> Birthplace: Corsicana, Texas </p>]
# Birth Date: ['March 31, 1928']
# Death Date: ['July 19, 1975']
# Birthplace: ['Corsicana, Texas']
# ==========================
# connie-b-gay
# https://countrymusichalloffame.org/artist/connie-b-gay/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 22, 1914 - Death: December 4, 1989 <br/> Birthplace: Lizard Lick, North Carolina </p>]
# Birth Date: ['August 22, 1914']
# Death Date: ['December 4, 1989']
# Birthplace: ['Lizard Lick, North Carolina']
# ==========================
# don-gibson
# https://countrymusichalloffame.org/artist/don-gibson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 3, 1928 - Death: November 17, 2003 <br/> Birthplace: Shelby, North Carolina </p>]
# Birth Date: ['April 3, 1928']
# Death Date: ['November 17, 2003']
# Birthplace: ['Shelby, North Carolina']
# ==========================
# vince-gill
# https://countrymusichalloffame.org/artist/vince-gill/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 12, 1957 <br/> Birthplace: Norman, Oklahoma </p>]
# Birth Date: ['April 12, 1957']
# Death Date: ['']
# Birthplace: ['Norman, Oklahoma']
# ==========================
# johnny-gimble
# https://countrymusichalloffame.org/artist/johnny-gimble/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 30, 1926 - Death: May 9, 2015 <br/> Birthplace: Tyler, Texas </p>]
# Birth Date: ['May 30, 1926']
# Death Date: ['May 9, 2015']
# Birthplace: ['Tyler, Texas']
# ==========================
# merle-haggard
# https://countrymusichalloffame.org/artist/merle-haggard/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 6, 1937 - Death: April 6, 2016 <br/> Birthplace: Bakersfield, California </p>]
# Birth Date: ['April 6, 1937']
# Death Date: ['April 6, 2016']
# Birthplace: ['Bakersfield, California']
# ==========================
# tom-t-hall
# https://countrymusichalloffame.org/artist/tom-t-hall/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 25, 1936 <br/> Birthplace: Olive Hill, Kentucky </p>]
# Birth Date: ['May 25, 1936']
# Death Date: ['']
# Birthplace: ['Olive Hill, Kentucky']
# ==========================
# emmylou-harris
# https://countrymusichalloffame.org/artist/emmylou-harris/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 2, 1947 <br/> Birthplace: Birmingham, Alabama </p>]
# Birth Date: ['April 2, 1947']
# Death Date: ['']
# Birthplace: ['Birmingham, Alabama']
# ==========================
# george-d-hay
# https://countrymusichalloffame.org/artist/george-d-hay/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 9, 1895 - Death: May 8, 1968 <br/> Birthplace: Attica, Indiana </p>]
# Birth Date: ['November 9, 1895']
# Death Date: ['May 8, 1968']
# Birthplace: ['Attica, Indiana']
# ==========================
# homer-and-jethro
# https://countrymusichalloffame.org/artist/homer-and-jethro/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# roy-horton
# https://countrymusichalloffame.org/artist/roy-horton/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 5, 1914 - Death: September 23, 2003 <br/> Birthplace: Near Broad Top, Pennsylvania </p>]
# Birth Date: ['November 5, 1914']
# Death Date: ['September 23, 2003']
# Birthplace: ['Near Broad Top, Pennsylvania']
# ==========================
# harlan-howard
# https://countrymusichalloffame.org/artist/harlan-howard/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 8, 1927 - Death: March 3, 2002 <br/> Birthplace: Detroit, Michigan </p>]
# Birth Date: ['September 8, 1927']
# Death Date: ['March 3, 2002']
# Birthplace: ['Detroit, Michigan']
# ==========================
# ferlin-husky
# https://countrymusichalloffame.org/artist/ferlin-husky/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 3, 1925 - Death: March 17, 2011 <br/> Birthplace: Cantwell, Missouri </p>]
# Birth Date: ['December 3, 1925']
# Death Date: ['March 17, 2011']
# Birthplace: ['Cantwell, Missouri']
# ==========================
# alan-jackson
# https://countrymusichalloffame.org/artist/alan-jackson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 17, 1958 <br/> Birthplace: Newnan, Georgia </p>]
# Birth Date: ['October 17, 1958']
# Death Date: ['']
# Birthplace: ['Newnan, Georgia']
# ==========================
# sonny-james
# https://countrymusichalloffame.org/artist/sonny-james/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 1, 1928 - Death: February 22, 2016 <br/> Birthplace: Hackleburg, Alabama </p>]
# Birth Date: ['May 1, 1928']
# Death Date: ['February 22, 2016']
# Birthplace: ['Hackleburg, Alabama']
# ==========================
# waylon-jennings
# https://countrymusichalloffame.org/artist/waylon-jennings/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: June 15, 1937 - Death: February 13, 2002 <br/> Birthplace: Littlefield, Texas </p>]
# Birth Date: ['June 15, 1937']
# Death Date: ['February 13, 2002']
# Birthplace: ['Littlefield, Texas']
# ==========================
# george-jones
# https://countrymusichalloffame.org/artist/george-jones/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 12, 1931 - Death: April 26, 2013 <br/> Birthplace: Saratoga, Texas </p>]
# Birth Date: ['September 12, 1931']
# Death Date: ['April 26, 2013']
# Birthplace: ['Saratoga, Texas']
# ==========================
# grandpa-jones
# https://countrymusichalloffame.org/artist/grandpa-jones/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 20, 1913 - Death: February 19, 1998 <br/> Birthplace: Niagra, Kentucky </p>]
# Birth Date: ['October 20, 1913']
# Death Date: ['February 19, 1998']
# Birthplace: ['Niagra, Kentucky']
# ==========================
# jordanaires
# https://countrymusichalloffame.org/artist/jordanaires/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# pee-wee-king
# https://countrymusichalloffame.org/artist/pee-wee-king/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 18, 1914 - Death: March 7, 2000 <br/> Birthplace: Milwaukee, Wisconsin </p>]
# Birth Date: ['February 18, 1914']
# Death Date: ['March 7, 2000']
# Birthplace: ['Milwaukee, Wisconsin']
# ==========================
# kris-kristofferson
# https://countrymusichalloffame.org/artist/kris-kristofferson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: June 22, 1936 <br/> Birthplace: Brownsville, Texas </p>]
# Birth Date: ['June 22, 1936']
# Death Date: ['']
# Birthplace: ['Brownsville, Texas']
# ==========================
# don-law
# https://countrymusichalloffame.org/artist/don-law/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 24, 1902 - Death: December 20, 1982 <br/> Birthplace: London, England </p>]
# Birth Date: ['February 24, 1902']
# Death Date: ['December 20, 1982']
# Birthplace: ['London, England']
# ==========================
# brenda-lee
# https://countrymusichalloffame.org/artist/brenda-lee/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 11, 1944 <br/> Birthplace: Atlanta, Georgia </p>]
# Birth Date: ['December 11, 1944']
# Death Date: ['']
# Birthplace: ['Atlanta, Georgia']
# ==========================
# hubert-long
# https://countrymusichalloffame.org/artist/hubert-long/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 3, 1923 - Death: September 7, 1972 <br/> Birthplace: Poteet, Texas </p>]
# Birth Date: ['December 3, 1923']
# Death Date: ['September 7, 1972']
# Birthplace: ['Poteet, Texas']
# ==========================
# the-louvin-brothers
# https://countrymusichalloffame.org/artist/the-louvin-brothers/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# loretta-lynn
# https://countrymusichalloffame.org/artist/loretta-lynn/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth:  April 14, 1935 <br/> Birthplace: Butcher Holler, Kentucky </p>]
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['Butcher Holler, Kentucky']
# ==========================
# uncle-david-macon
# https://countrymusichalloffame.org/artist/uncle-david-macon/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 7, 1870 - Death: March 22, 1952 <br/> Birthplace: Smart Station, Warren County, Tennessee </p>]
# Birth Date: ['October 7, 1870']
# Death Date: ['March 22, 1952']
# Birthplace: ['Smart Station, Warren County, Tennessee']
# ==========================
# barbara-mandrell
# https://countrymusichalloffame.org/artist/barbara-mandrell/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 25, 1948 <br/> Birthplace: Houston, Texas </p>]
# Birth Date: ['December 25, 1948']
# Death Date: ['']
# Birthplace: ['Houston, Texas']
# ==========================
# grady-martin
# https://countrymusichalloffame.org/artist/grady-martin/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 17, 1929 - Death: December 3, 2001 <br/> Birthplace: Marshall County, Tennessee </p>]
# Birth Date: ['January 17, 1929']
# Death Date: ['December 3, 2001']
# Birthplace: ['Marshall County, Tennessee']
# ==========================
# charlie-mccoy
# https://countrymusichalloffame.org/artist/charlie-mccoy/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 28, 1941 <br/> Birthplace: Oak Hill, West Virginia </p>]
# Birth Date: ['March 28, 1941']
# Death Date: ['']
# Birthplace: ['Oak Hill, West Virginia']
# ==========================
# reba-mcentire
# https://countrymusichalloffame.org/artist/reba-mcentire/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 28, 1955 <br/> Birthplace: McAlester, Oklahoma </p>]
# Birth Date: ['March 28, 1955']
# Death Date: ['']
# Birthplace: ['McAlester, Oklahoma']
# ==========================
# roger-miller
# https://countrymusichalloffame.org/artist/roger-miller/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 2, 1936 - Death: October 25, 1992 <br/> Birthplace: Fort Worth, Texas </p>]
# Birth Date: ['January 2, 1936']
# Death Date: ['October 25, 1992']
# Birthplace: ['Fort Worth, Texas']
# ==========================
# ronnie-milsap
# https://countrymusichalloffame.org/artist/ronnie-milsap/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 16, 1943 <br/> Birthplace: Robbinsville, North Carolina </p>]
# Birth Date: ['January 16, 1943']
# Death Date: ['']
# Birthplace: ['Robbinsville, North Carolina']
# ==========================
# bill-monroe
# https://countrymusichalloffame.org/artist/bill-monroe/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 13, 1911 - Death: September 9, 1996 <br/> Birthplace: Rosine, Kentucky </p>]
# Birth Date: ['September 13, 1911']
# Death Date: ['September 9, 1996']
# Birthplace: ['Rosine, Kentucky']
# ==========================
# patsy-montana
# https://countrymusichalloffame.org/artist/patsy-montana/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 30, 1908 - Death: May 3, 1996 <br/> Birthplace: Hope, Arkansas </p>]
# Birth Date: ['October 30, 1908']
# Death Date: ['May 3, 1996']
# Birthplace: ['Hope, Arkansas']
# ==========================
# george-morgan
# https://countrymusichalloffame.org/artist/george-morgan/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: June 28, 1924 - Death: July 7, 1975 <br/> Birthplace: Waverly, Tennessee </p>]
# Birth Date: ['June 28, 1924']
# Death Date: ['July 7, 1975']
# Birthplace: ['Waverly, Tennessee']
# ==========================
# ken-nelson
# https://countrymusichalloffame.org/artist/ken-nelson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 19, 1911 - Death: January 6, 2008 <br/> Birthplace: Caledonia, Minnesota </p>]
# Birth Date: ['January 19, 1911']
# Death Date: ['January 6, 2008']
# Birthplace: ['Caledonia, Minnesota']
# ==========================
# willie-nelson
# https://countrymusichalloffame.org/artist/willie-nelson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: April 29, 1933 <br/> Birthplace: Abbott, Texas </p>]
# Birth Date: ['April 29, 1933']
# Death Date: ['']
# Birthplace: ['Abbott, Texas']
# ==========================
# oak-ridge-boys
# https://countrymusichalloffame.org/artist/oak-ridge-boys/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# buck-owens
# https://countrymusichalloffame.org/artist/buck-owens/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 12, 1929 - Death: March 25, 2006 <br/> Birthplace: Sherman, Texas </p>]
# Birth Date: ['August 12, 1929']
# Death Date: ['March 25, 2006']
# Birthplace: ['Sherman, Texas']
# ==========================
# dolly-parton
# https://countrymusichalloffame.org/artist/dolly-parton/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 19, 1946 <br/> Birthplace: Locust Ridge, Tennessee </p>]
# Birth Date: ['January 19, 1946']
# Death Date: ['']
# Birthplace: ['Locust Ridge, Tennessee']
# ==========================
# minnie-pearl
# https://countrymusichalloffame.org/artist/minnie-pearl/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 25, 1912 - Death: March 4, 1996 <br/> Birthplace: Centerville, Tennessee </p>]
# Birth Date: ['October 25, 1912']
# Death Date: ['March 4, 1996']
# Birthplace: ['Centerville, Tennessee']
# ==========================
# ralph-peer
# https://countrymusichalloffame.org/artist/ralph-peer/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 22, 1892 - Death: January 19, 1960 <br/> Birthplace: Kansas City, Missouri </p>]
# Birth Date: ['May 22, 1892']
# Death Date: ['January 19, 1960']
# Birthplace: ['Kansas City, Missouri']
# ==========================
# sam-phillips
# https://countrymusichalloffame.org/artist/sam-phillips/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 5, 1923 - Death: July 30, 2003 <br/> Birthplace: Florence, Alabama </p>]
# Birth Date: ['January 5, 1923']
# Death Date: ['July 30, 2003']
# Birthplace: ['Florence, Alabama']
# ==========================
# webb-pierce
# https://countrymusichalloffame.org/artist/webb-pierce/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 8, 1921 - Death: February 24, 1991 <br/> Birthplace: West Monroe, Louisiana </p>]
# Birth Date: ['August 8, 1921']
# Death Date: ['February 24, 1991']
# Birthplace: ['West Monroe, Louisiana']
# ==========================
# elvis-presley
# https://countrymusichalloffame.org/artist/elvis-presley/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 8, 1935 - Death: August 16, 1977 <br/> Birthplace: Tupelo, Mississippi </p>]
# Birth Date: ['January 8, 1935']
# Death Date: ['August 16, 1977']
# Birthplace: ['Tupelo, Mississippi']
# ==========================
# frances-preston
# https://countrymusichalloffame.org/artist/frances-preston/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 27, 1928 - Death: June 13, 2012 <br/> Birthplace: Nashville, Tennessee </p>]
# Birth Date: ['August 27, 1928']
# Death Date: ['June 13, 2012']
# Birthplace: ['Nashville, Tennessee']
# ==========================
# ray-price
# https://countrymusichalloffame.org/artist/ray-price/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 12, 1926 - Death: December 16, 2013 <br/> Birthplace: Perryville, Texas </p>]
# Birth Date: ['January 12, 1926']
# Death Date: ['December 16, 2013']
# Birthplace: ['Perryville, Texas']
# ==========================
# charley-pride
# https://countrymusichalloffame.org/artist/charley-pride/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 18, 1934 <br/> Birthplace: Sledge, Mississippi </p>]
# Birth Date: ['March 18, 1934']
# Death Date: ['']
# Birthplace: ['Sledge, Mississippi']
# ==========================
# jerry-reed
# https://countrymusichalloffame.org/artist/jerry-reed/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# jim-reeves
# https://countrymusichalloffame.org/artist/jim-reeves/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 20, 1923 - Death: July 31, 1964 <br/> Birthplace: Panola County, Texas </p>]
# Birth Date: ['August 20, 1923']
# Death Date: ['July 31, 1964']
# Birthplace: ['Panola County, Texas']
# ==========================
# tex-ritter
# https://countrymusichalloffame.org/artist/tex-ritter/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 12, 1905 - Death: January 2, 1974 <br/> Birthplace: Panola County, Texas </p>]
# Birth Date: ['January 12, 1905']
# Death Date: ['January 2, 1974']
# Birthplace: ['Panola County, Texas']
# ==========================
# hargus-pig-robbins
# https://countrymusichalloffame.org/artist/hargus-pig-robbins/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 18, 1938 <br/> Birthplace: Rhea County, Tennessee </p>]
# Birth Date: ['January 18, 1938']
# Death Date: ['']
# Birthplace: ['Rhea County, Tennessee']
# ==========================
# marty-robbins
# https://countrymusichalloffame.org/artist/marty-robbins/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 26, 1925 - Death: December 8, 1982 <br/> Birthplace: Near Glendale, Arizona </p>]
# Birth Date: ['September 26, 1925']
# Death Date: ['December 8, 1982']
# Birthplace: ['Near Glendale, Arizona']
# ==========================
# jimmie-rodgers
# https://countrymusichalloffame.org/artist/jimmie-rodgers/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 8, 1897 - Death: May 26, 1933 <br/> Birthplace: Meridian, Mississippi </p>]
# Birth Date: ['September 8, 1897']
# Death Date: ['May 26, 1933']
# Birthplace: ['Meridian, Mississippi']
# ==========================
# kenny-rogers
# https://countrymusichalloffame.org/artist/kenny-rogers/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 21, 1938 - Death: March 20, 2020 <br/> Birthplace: Houston, Texas </p>]
# Birth Date: ['August 21, 1938']
# Death Date: ['March 20, 2020']
# Birthplace: ['Houston, Texas']
# ==========================
# roy-rogers
# https://countrymusichalloffame.org/artist/roy-rogers/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 5, 1911 - Death: July 6, 1998 <br/> Birthplace: Cincinnati, Ohio </p>]
# Birth Date: ['November 5, 1911']
# Death Date: ['July 6, 1998']
# Birthplace: ['Cincinnati, Ohio']
# ==========================
# fred-rose
# https://countrymusichalloffame.org/artist/fred-rose/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 24, 1898 - Death: December 1, 1954 <br/> Birthplace: Evansville, Indiana </p>]
# Birth Date: ['August 24, 1898']
# Death Date: ['December 1, 1954']
# Birthplace: ['Evansville, Indiana']
# ==========================
# wesley-rose
# https://countrymusichalloffame.org/artist/wesley-rose/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 11, 1918 - Death: April 26, 1990 <br/> Birthplace: Chicago, Illinois </p>]
# Birth Date: ['February 11, 1918']
# Death Date: ['April 26, 1990']
# Birthplace: ['Chicago, Illinois']
# ==========================
# arthur-e-satherley
# https://countrymusichalloffame.org/artist/arthur-e-satherley/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 19, 1889 - Death: February 10, 1986 <br/> Birthplace: Bristol, England </p>]
# Birth Date: ['October 19, 1889']
# Death Date: ['February 10, 1986']
# Birthplace: ['Bristol, England']
# ==========================
# don-schlitz
# https://countrymusichalloffame.org/artist/don-schlitz/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 29, 1952 <br/> Birthplace: Durham, North Carolina </p>]
# Birth Date: ['August 29, 1952']
# Death Date: ['']
# Birthplace: ['Durham, North Carolina']
# ==========================
# jean-shepard
# https://countrymusichalloffame.org/artist/jean-shepard/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 21, 1933 - Death: September 25, 2016 <br/> Birthplace: Pauls Valley, Oklahoma </p>]
# Birth Date: ['November 21, 1933']
# Death Date: ['September 25, 2016']
# Birthplace: ['Pauls Valley, Oklahoma']
# ==========================
# billy-sherrill
# https://countrymusichalloffame.org/artist/billy-sherrill/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 5, 1936 - Death: August 4, 2015 <br/> Birthplace: Phil Campbell, Alabama </p>]
# Birth Date: ['November 5, 1936']
# Death Date: ['August 4, 2015']
# Birthplace: ['Phil Campbell, Alabama']
# ==========================
# stephen-sholes
# https://countrymusichalloffame.org/artist/stephen-sholes/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 12, 1911 - Death: April 22, 1968 <br/> Birthplace: Washington, D.C. </p>]
# Birth Date: ['February 12, 1911']
# Death Date: ['April 22, 1968']
# Birthplace: ['Washington, D.C.']
# ==========================
# ricky-skaggs
# https://countrymusichalloffame.org/artist/ricky-skaggs/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: July 18, 1954 <br/> Birthplace: Cordell, Kentucky </p>]
# Birth Date: ['July 18, 1954']
# Death Date: ['']
# Birthplace: ['Cordell, Kentucky']
# ==========================
# carl-smith
# https://countrymusichalloffame.org/artist/carl-smith/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 15, 1927 - Death: January 16, 2010 <br/> Birthplace: Maynardville, Tennessee </p>]
# Birth Date: ['March 15, 1927']
# Death Date: ['January 16, 2010']
# Birthplace: ['Maynardville, Tennessee']
# ==========================
# connie-smith
# https://countrymusichalloffame.org/artist/connie-smith/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 14, 1941 <br/> Birthplace: Elkhart, Indiana </p>]
# Birth Date: ['August 14, 1941']
# Death Date: ['']
# Birthplace: ['Elkhart, Indiana']
# ==========================
# hank-snow
# https://countrymusichalloffame.org/artist/hank-snow/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 9, 1914 - Death: December 20, 1999 <br/> Birthplace: Brooklyn, Nova Scotia, Canada </p>]
# Birth Date: ['May 9, 1914']
# Death Date: ['December 20, 1999']
# Birthplace: ['Brooklyn, Nova Scotia, Canada']
# ==========================
# sons-of-the-pioneers
# https://countrymusichalloffame.org/artist/sons-of-the-pioneers/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# jack-stapp
# https://countrymusichalloffame.org/artist/jack-stapp/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 8, 1912 - Death: December 20, 1980 <br/> Birthplace: Nashville, Tennessee </p>]
# Birth Date: ['December 8, 1912']
# Death Date: ['December 20, 1980']
# Birthplace: ['Nashville, Tennessee']
# ==========================
# ray-stevens
# https://countrymusichalloffame.org/artist/ray-stevens/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: January 24, 1939 <br/> Birthplace: Clarkdale, Georgia </p>]
# Birth Date: ['January 24, 1939']
# Death Date: ['']
# Birthplace: ['Clarkdale, Georgia']
# ==========================
# cliffie-stone
# https://countrymusichalloffame.org/artist/cliffie-stone/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 1, 1917 - Death: January 17, 1998 <br/> Birthplace: Stockton, California </p>]
# Birth Date: ['March 1, 1917']
# Death Date: ['January 17, 1998']
# Birthplace: ['Stockton, California']
# ==========================
# ernest-v-pop-stoneman
# https://countrymusichalloffame.org/artist/ernest-v-pop-stoneman/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 25, 1893 - Death: June 14, 1968 <br/> Birthplace: Monarat, Virginia </p>]
# Birth Date: ['May 25, 1893']
# Death Date: ['June 14, 1968']
# Birthplace: ['Monarat, Virginia']
# ==========================
# george-strait
# https://countrymusichalloffame.org/artist/george-strait/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 18, 1952 <br/> Birthplace: Poteet, Texas </p>]
# Birth Date: ['May 18, 1952']
# Death Date: ['']
# Birthplace: ['Poteet, Texas']
# ==========================
# the-duke-of-paducah
# https://countrymusichalloffame.org/artist/the-duke-of-paducah/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 12, 1901 - Death: June 20, 1986 <br/> Birthplace: DeSoto, Missouri </p>]
# Birth Date: ['May 12, 1901']
# Death Date: ['June 20, 1986']
# Birthplace: ['DeSoto, Missouri']
# ==========================
# the-statler-brothers
# https://countrymusichalloffame.org/artist/the-statler-brothers/
# []
# Birth Date: ['']
# Death Date: ['']
# Birthplace: ['']
# ==========================
# hank-thompson
# https://countrymusichalloffame.org/artist/hank-thompson/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 3, 1925 - Death: November 6, 2007 <br/> Birthplace: Waco, Texas </p>]
# Birth Date: ['September 3, 1925']
# Death Date: ['November 6, 2007']
# Birthplace: ['Waco, Texas']
# ==========================
# mel-tillis
# https://countrymusichalloffame.org/artist/mel-tillis/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 8, 1932 - Death: November 19, 2017 <br/> Birthplace: Tampa, Florida </p>]
# Birth Date: ['August 8, 1932']
# Death Date: ['November 19, 2017']
# Birthplace: ['Tampa, Florida']
# ==========================
# floyd-tillman
# https://countrymusichalloffame.org/artist/floyd-tillman/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: December 8, 1914 - Death: August 22, 2003 <br/> Birthplace: Ryan, Oklahoma </p>]
# Birth Date: ['December 8, 1914']
# Death Date: ['August 22, 2003']
# Birthplace: ['Ryan, Oklahoma']
# ==========================
# merle-travis
# https://countrymusichalloffame.org/artist/merle-travis/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: November 29, 1917 - Death: October 20, 1983 <br/> Birthplace: Rosewood, Kentucky </p>]
# Birth Date: ['November 29, 1917']
# Death Date: ['October 20, 1983']
# Birthplace: ['Rosewood, Kentucky']
# ==========================
# randy-travis
# https://countrymusichalloffame.org/artist/randy-travis/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 4, 1959 <br/> Birthplace: Marshville, North Carolina </p>]
# Birth Date: ['May 4, 1959']
# Death Date: ['']
# Birthplace: ['Marshville, North Carolina']
# ==========================
# ernest-tubb
# https://countrymusichalloffame.org/artist/ernest-tubb/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 9, 1914 - Death: September 6, 1984 <br/> Birthplace: Near Crisp, Texas </p>]
# Birth Date: ['February 9, 1914']
# Death Date: ['September 6, 1984']
# Birthplace: ['Near Crisp, Texas']
# ==========================
# grant-turner
# https://countrymusichalloffame.org/artist/grant-turner/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 17, 1912 - Death: October 19, 1991 <br/> Birthplace: Baird, Texas </p>]
# Birth Date: ['May 17, 1912']
# Death Date: ['October 19, 1991']
# Birthplace: ['Baird, Texas']
# ==========================
# conway-twitty
# https://countrymusichalloffame.org/artist/conway-twitty/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 1, 1933 - Death: June 5, 1993 <br/> Birthplace: Friars Point, Mississippi </p>]
# Birth Date: ['September 1, 1933']
# Death Date: ['June 5, 1993']
# Birthplace: ['Friars Point, Mississippi']
# ==========================
# porter-wagoner
# https://countrymusichalloffame.org/artist/porter-wagoner/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 12, 1927 - Death: October 28, 2007 <br/> Birthplace: Howell County, Missouri </p>]
# Birth Date: ['August 12, 1927']
# Death Date: ['October 28, 2007']
# Birthplace: ['Howell County, Missouri']
# ==========================
# cindy-walker
# https://countrymusichalloffame.org/artist/cindy-walker/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: July 20, 1918 - Death: March 23, 2006 <br/> Birthplace: Mart, Texas </p>]
# Birth Date: ['July 20, 1918']
# Death Date: ['March 23, 2006']
# Birthplace: ['Mart, Texas']
# ==========================
# jo-walker-meador
# https://countrymusichalloffame.org/artist/jo-walker-meador/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 16, 1924 - Death: August 16, 2017 <br/> Birthplace: Orlinda, Tennessee </p>]
# Birth Date: ['February 16, 1924']
# Death Date: ['August 16, 2017']
# Birthplace: ['Orlinda, Tennessee']
# ==========================
# kitty-wells
# https://countrymusichalloffame.org/artist/kitty-wells/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 30, 1919 - Death: July 16, 2012 <br/> Birthplace: Nashville, Tennessee </p>]
# Birth Date: ['August 30, 1919']
# Death Date: ['July 16, 2012']
# Birthplace: ['Nashville, Tennessee']
# ==========================
# e-w-bud-wendell
# https://countrymusichalloffame.org/artist/e-w-bud-wendell/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: August 17, 1927 <br/> Birthplace: Akron, Ohio </p>]
# Birth Date: ['August 17, 1927']
# Death Date: ['']
# Birthplace: ['Akron, Ohio']
# ==========================
# dottie-west
# https://countrymusichalloffame.org/artist/dottie-west/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: October 11, 1932 - Death: September 4, 1991 <br/> Birthplace: McMinnville, Tennessee </p>]
# Birth Date: ['October 11, 1932']
# Death Date: ['September 4, 1991']
# Birthplace: ['McMinnville, Tennessee']
# ==========================
# don-williams
# https://countrymusichalloffame.org/artist/don-williams/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 27, 1939 - Death: September 8, 2017 <br/> Birthplace: Floydada, Texas </p>]
# Birth Date: ['May 27, 1939']
# Death Date: ['September 8, 2017']
# Birthplace: ['Floydada, Texas']
# ==========================
# hank-williams
# https://countrymusichalloffame.org/artist/hank-williams/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: September 17, 1923 - Death: January 1, 1953 <br/> Birthplace: Mount Olive, Alabama </p>]
# Birth Date: ['September 17, 1923']
# Death Date: ['January 1, 1953']
# Birthplace: ['Mount Olive, Alabama']
# ==========================
# bob-wills
# https://countrymusichalloffame.org/artist/bob-wills/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: March 6, 1905 - Death: May 13, 1975 <br/> Birthplace: Kosse, Texas </p>]
# Birth Date: ['March 6, 1905']
# Death Date: ['May 13, 1975']
# Birthplace: ['Kosse, Texas']
# ==========================
# mac-wiseman
# https://countrymusichalloffame.org/artist/mac-wiseman/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 23, 1925 - Death: February 24, 2019 <br/> Birthplace: Crimora, Virginia </p>]
# Birth Date: ['May 23, 1925']
# Death Date: ['February 24, 2019']
# Birthplace: ['Crimora, Virginia']
# ==========================
# tammy-wynette
# https://countrymusichalloffame.org/artist/tammy-wynette/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: May 5, 1942 - Death: April 6, 1998 <br/> Birthplace: Itawamba County, Mississippi </p>]
# Birth Date: ['May 5, 1942']
# Death Date: ['April 6, 1998']
# Birthplace: ['Itawamba County, Mississippi']
# ==========================
# faron-young
# https://countrymusichalloffame.org/artist/faron-young/
# [<p style="margin-top: 20px;color: #50565A;font-size: 14px;font-weight: 500;letter-spacing: 1.5px;line-height: 25px; text-transform: uppercase;">Birth: February 25, 1932 - Death: December 10, 1996 <br/> Birthplace: Shreveport, Louisiana </p>]
# Birth Date: ['February 25, 1932']
# Death Date: ['December 10, 1996']
# Birthplace: ['Shreveport, Louisiana']
# ==========================

# %%
bonus_df = pd.DataFrame(
    {
        "artist": all_artists,
        "year_inducted": all_years_inducted,
        "birth_date": births,
        "death_date": deaths,
        "birth_place":  birthplaces
    }
)

bonus_df
# Out:
#             artist  year_inducted          birth_date         death_date  \
# 0        Roy Acuff           1962  September 15, 1903  November 23, 1992
# 1          Alabama           2005
# 2    Bill Anderson           2001    November 1, 1937
# 3      Eddy Arnold           1966        May 15, 1918        May 8, 2008
# 4      Chet Atkins           1973       June 20, 1924      June 30, 2001
# ..             ...            ...                 ...                ...
# 135  Hank Williams           1961  September 17, 1923    January 1, 1953
# 136      Bob Wills           1968       March 6, 1905       May 13, 1975
# 137    Mac Wiseman           2014        May 23, 1925  February 24, 2019
# 138  Tammy Wynette           1998         May 5, 1942      April 6, 1998
# 139    Faron Young           2000   February 25, 1932  December 10, 1996
#
#                       birth_place
# 0         Maynardville, Tennessee
# 1
# 2        Columbia, South Carolina
# 3            Henderson, Tennessee
# 4             Luttrell, Tennessee
# ..                            ...
# 135          Mount Olive, Alabama
# 136                  Kosse, Texas
# 137             Crimora, Virginia
# 138  Itawamba County, Mississippi
# 139         Shreveport, Louisiana
#
# [140 rows x 5 columns]
